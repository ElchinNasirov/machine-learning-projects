# %%
# Statistics Basics – Mean, Variance, Hypothesis Testing + Pandas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

print("=== Statistics with Pandas (Iris Dataset) ===\n")

# Load Iris dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

print("First 5 rows:")
print(df.head())

print("\nBasic Statistics:")
print(df.describe())

# Mean and Variance
print("\nMean of sepal length:", df['sepal length (cm)'].mean())
print("Variance of sepal length:", df['sepal length (cm)'].var())

# Group by target (species)
print("\nMean by species:")
print(df.groupby('target').mean())

print("\n Completed successfully!")
# Out:
# === Statistics with Pandas (Iris Dataset) ===
#
# First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#
# Basic Statistics:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# ...
